# %% [markdown]
# # Parameterised Notebook Template
#
# Designed for papermill runs. The next code cell is tagged `parameters`.

# %%
ticker = 'AAPL'
lookback = 30
metric = 'Close'

# %%
print(f'Running analysis for {ticker} over {lookback} days using {metric}.')
