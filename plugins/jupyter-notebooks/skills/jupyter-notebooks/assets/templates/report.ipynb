# %% [markdown]
# # Analysis Report
#
# Use this template for markdown-first reporting with embedded figures.

# %% [markdown]
# ## Executive Summary
#
# Write the top findings and implications here.

# %% [markdown]
# ## Method
#
# Document assumptions, data sources, and processing logic.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 3, 5, 8]
plt.figure(figsize=(6, 3))
plt.plot(x, y, marker='o')
plt.title('Example Figure')
plt.xlabel('x')
plt.ylabel('y')
plt.tight_layout()

# %% [markdown]
# ## Conclusion
#
# Summarize decisions, risks, and follow-up actions.
